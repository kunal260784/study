# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
llm = init_chat_model(model= "gpt-4o-mini", model_provider="openai", temperature = 0,
                      max_tokens = 1000
                    )

# %%
result = llm.invoke("difference between DAX and M query")

# %%
print(result.content)
# Out:
# DAX (Data Analysis Expressions) and M (Power Query Formula Language) are both languages used in Microsoft Power BI, Excel, and other Microsoft products, but they serve different purposes and are used in different contexts. Here’s a breakdown of their differences:
#
# ### Purpose
#
# - **DAX (Data Analysis Expressions)**:
#   - DAX is primarily used for data modeling and analysis. It is designed for creating calculated columns, measures, and calculated tables in data models.
#   - DAX is optimized for querying and performing calculations on data that is already loaded into the data model.
#
# - **M (Power Query Formula Language)**:
#   - M is used for data transformation and preparation. It is the language behind Power Query, which is used to connect to, import, and transform data from various sources before it is loaded into the data model.
#   - M is focused on data extraction, transformation, and loading (ETL) processes.
#
# ### Context of Use
#
# - **DAX**:
#   - Used in the data model layer of Power BI and Excel.
#   - Commonly used in creating measures and calculated columns that are evaluated in the context of the data model.
#   - DAX functions are often used in visualizations to aggregate and analyze data.
#
# - **M**:
#   - Used in the Power Query Editor to shape and transform data before it is loaded into the data model.
#   - M functions are used to filter, merge, append, and perform other transformations on data sources.
#
# ### Syntax and Structure
#
# - **DAX**:
#   - DAX has a syntax that is similar to Excel formulas, with functions like `SUM`, `AVERAGE`, `CALCULATE`, and `FILTER`.
#   - DAX operates on tables and columns, and it uses row context and filter context to evaluate expressions.
#
# - **M**:
#   - M has a different syntax that is more functional and less formulaic than DAX. It uses functions like `Table.SelectRows`, `Table.AddColumn`, and `Text.Upper`.
#   - M is more focused on data manipulation and transformation steps, often represented as a series of applied steps in the Power Query Editor.
#
# ### Performance
#
# - **DAX**:
#   - DAX is optimized for performance in querying large datasets and is designed to work efficiently with in-memory data models.
#
# - **M**:
#   - M is optimized for data transformation and can handle various data sources and types, but it may not be as performant as DAX when it comes to querying large datasets after they have been loaded into the model.
#
# ### Summary
#
# In summary, DAX is used for data analysis and calculations within the data model, while M is used for data transformation and preparation before the data is loaded into the model. Understanding both languages is essential for effectively working with Power BI and Excel for data analysis and reporting.
