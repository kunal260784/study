# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
llm = init_chat_model(model= "gpt-4o-mini", model_provider="openai", temperature = 0,
                      max_tokens = 1000
                    )

# %%
result = llm.invoke("difference between DAX and M query")

# %%
print(result.content)
# Out:
# DAX (Data Analysis Expressions) and M (Power Query Formula Language) are both languages used in Microsoft Power BI, Excel, and other Microsoft products, but they serve different purposes and are used in different contexts. Here’s a breakdown of their differences:
#
# ### Purpose
#
# - **DAX (Data Analysis Expressions)**:
#   - Primarily used for data modeling and analysis.
#   - Designed for creating calculated columns, measures, and calculated tables in data models.
#   - Focuses on data aggregation, filtering, and calculations on data that is already loaded into the model.
#
# - **M (Power Query Formula Language)**:
#   - Used for data transformation and preparation.
#   - Designed for querying and shaping data before it is loaded into the data model.
#   - Focuses on data extraction, transformation, and loading (ETL) processes.
#
# ### Context of Use
#
# - **DAX**:
#   - Used in the data model layer of Power BI and Excel.
#   - Commonly used in creating measures for reports and dashboards.
#   - Works with data that is already in the model, allowing for dynamic calculations based on user interactions.
#
# - **M**:
#   - Used in the Power Query Editor.
#   - Commonly used for importing data from various sources, cleaning, and transforming it before it is loaded into the data model.
#   - Works with raw data and is often the first step in the data preparation process.
#
# ### Syntax and Structure
#
# - **DAX**:
#   - Syntax is similar to Excel formulas but includes functions specifically designed for data analysis.
#   - Supports context (row context and filter context) which affects how calculations are performed.
#   - Example: `Total Sales = SUM(Sales[SalesAmount])`
#
# - **M**:
#   - Syntax is more functional and less formulaic than DAX.
#   - Uses a series of steps to transform data, often represented as a sequence of applied transformations.
#   - Example:
#     ```m
#     let
#         Source = Excel.Workbook(File.Contents("C:\Data.xlsx")),
#         SalesData = Source{[Name="Sales"]}[Data],
#         FilteredData = Table.SelectRows(SalesData, each [SalesAmount] > 100)
#     in
#         FilteredData
#     ```
#
# ### Performance
#
# - **DAX**:
#   - Optimized for in-memory calculations and can handle large datasets efficiently.
#   - Performance can be affected by the complexity of the calculations and the size of the data model.
#
# - **M**:
#   - Performance can vary based on the data source and the complexity of the transformations.
#   - Generally, M queries are executed when data is loaded or refreshed, and the performance can be influenced by the efficiency of the data source.
#
# ### Summary
#
# In summary, DAX is used for calculations and data analysis within the data model, while M is used for data transformation and preparation before the data is loaded into the model. Understanding both languages is essential for effective data modeling and reporting in Power BI and Excel.
