# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
llm = init_chat_model(model= "gpt-4o-mini", model_provider="openai", temperature = 0,
                      max_tokens = 1000
                    )

# %%
for chunk in llm.stream("difference between DAX and M query"):
    print(chunk.text, end = "")
# Out:
# DAX (Data Analysis Expressions) and M (Power Query Formula Language) are both languages used in Microsoft Power BI, Excel, and other Microsoft products, but they serve different purposes and are used in different contexts. Here’s a breakdown of the differences between the two:
#
# ### Purpose
#
# - **DAX (Data Analysis Expressions)**:
#   - DAX is primarily used for data analysis and calculations. It is designed to work with data models and is used to create calculated columns, measures, and calculated tables in Power BI and Excel.
#   - DAX is optimized for querying and aggregating data, making it suitable for creating complex calculations and metrics in reports and dashboards.
#
# - **M (Power Query Formula Language)**:
#   - M is used for data transformation and preparation. It is the language behind Power Query, which is used to connect to, import, and transform data from various sources before loading it into the data model.
#   - M is designed for data manipulation tasks such as filtering, merging, and reshaping data.
#
# ### Syntax and Structure
#
# - **DAX**:
#   - DAX syntax is similar to Excel formulas and is designed to work with tables and columns. It uses functions like `SUM`, `AVERAGE`, `CALCULATE`, and many others to perform calculations.
#   - DAX operates on data that is already loaded into the data model.
#
# - **M**:
#   - M has a different syntax and is more functional in nature. It uses functions like `Table.SelectRows`, `Table.AddColumn`, and `Text.Upper` to manipulate data.
#   - M operates on data as it is being imported and transformed, allowing for a wide range of data preparation tasks.
#
# ### Execution Context
#
# - **DAX**:
#   - DAX calculations are executed at the time of data visualization or when a report is refreshed. It is evaluated in the context of the data model and the filters applied to it.
#
# - **M**:
#   - M queries are executed during the data loading process. When you refresh your data in Power BI or Excel, the M queries are run to transform the data before it is loaded into the data model.
#
# ### Use Cases
#
# - **DAX**:
#   - Creating dynamic calculations for reports (e.g., year-to-date sales, running totals).
#   - Building KPIs and metrics that respond to user interactions in reports.
#
# - **M**:
#   - Importing data from various sources (e.g., databases, Excel files, web services).
#   - Cleaning and transforming data (e.g., removing duplicates, changing data types, pivoting/unpivoting data).
#
# ### Summary
#
# In summary, DAX is focused on data analysis and calculations within the data model, while M is focused on data transformation and preparation before the data is loaded into the model. Understanding both languages is essential for effectively working with Power BI and Excel for data analysis and reporting.
