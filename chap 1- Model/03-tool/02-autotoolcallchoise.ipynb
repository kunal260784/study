# %%
from langchain.tools import tool
from langchain.chat_models import init_chat_model
from langchain.messages import SystemMessage, AIMessage, HumanMessage
from pprint import pprint

# %%
@tool
def add(a:float, b:float) -> float:

    """
    add Function is created to perform addition of two Numbers.
    
    :param a: First Number to Perform Addition
    :type a: float
    :param b: Second Number to Perform Addition
    :type b: float

    :return: Sum of given two Numbers
    :rtype: float

    ..code-block :: python
        #example

        >>> add(1.0,2.3)
        3.3

        >>> add(2,5)
        7.0
    """
    return a + b



@tool
def Subtract(a:float, b:float) -> float:

    """
    Subtract Function is created to perform Subtraction of two Numbers.
    
    :param a: First Number to Perform Addition
    :type a: float
    :param b: Second Number to Perform Addition
    :type b: float

    :return: Subtract second number from first one.
    :rtype: float

    ..code-block :: python
        #example

        >>> Subtract(1.0,2.3)
        -1.3

        >>> Subtract(5,1)
        4.0
    """
    return a - b

# %%
llm = init_chat_model(
    model="gpt-4o-mini",
    model_provider="openai"
)

llm_tool = llm.bind_tools([add,Subtract], tool_choice="none")

# %%
result = llm_tool.invoke("multiply 2 and 3")
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# It seems that multiplication is not a function I can perform. However, I can add or subtract numbers. Would you like me to perform addition or subtraction with those numbers?

# %%
result = llm.invoke("Subtract 2 from 1.5")
print(result)
# Out:
# content='1.5 - 2 = -0.5.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 15, 'total_tokens': 27, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_11f3029f6b', 'id': 'chatcmpl-Cm1yVnQOSumEESg9VBZqKvTg6ENuX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b13c7-1513-7742-a81a-26fb830b4595-0' usage_metadata={'input_tokens': 15, 'output_tokens': 12, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
