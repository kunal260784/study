# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
from pprint import pprint
import os

# %%
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
wikitool = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(
    top_k_results=3,
    doc_content_chars_max=2000
))

tavilytool = TavilySearch(max_results=5, topic="general")

# %%
llm = init_chat_model(
    model="gpt-4o-mini",
    model_provider="openai",
    temperature=0,
)

# %%
llmagent = create_agent(
    model=llm,
    tools=[wikitool, tavilytool],
    system_prompt="You are a power BI expert and can answer the questions related to Power BI only"
)

# %%
result = llmagent.invoke({"messages":"What is Power BI"})

# %%
for item in result['messages']:
    item.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is Power BI
# ================================== Ai Message ==================================
#
# Power BI is a business analytics tool developed by Microsoft that enables users to visualize data, share insights, and make data-driven decisions. It provides interactive visualizations and business intelligence capabilities with an interface that is easy to use for non-technical users.
#
# Key features of Power BI include:
#
# 1. **Data Connectivity**: Power BI can connect to a wide range of data sources, including databases, cloud services, and spreadsheets.
#
# 2. **Data Transformation**: Users can clean, transform, and model data using Power Query, allowing for better analysis.
#
# 3. **Visualizations**: Power BI offers a variety of visualization options, such as charts, graphs, maps, and dashboards, to represent data in an understandable way.
#
# ...
